# %%
import pandas as pd

# %%
data = pd.read_csv('test.csv')
data.head()
# Out:
#         id                                            comment  product_id  \
# 0  1052439  معمولیه و زیاد کیفیتشم خوب نیست ولی در کل زیاد...     3746235
# 1  1130800               جنس خوبی داره با این قدر پول می ارزه     2738072
# 2  1177330                                     ایییی بدک نیست     1919416
# 3  1047314             خوبه بااین قیمت بهتر از این نمیشه گرفت     1816187
# 4  1096710                                    زیبا بود و ظریف     2158649
#
#                                     product_title_fa  category_id  \
# 0  کابل تبدیل USB به microUSB تسکو مدل TC A93 طول...           80
# 1  پایه نگهدارنده گوشی موبایل مدل LS010 مجموعه 8 ...           81
# 2        فلش مموری دی ام مدل PD135 ظرفیت 32 گیگابایت           64
# 3  محافظ صفحه نمایش تراستکتور مدل GSS مناسب برای ...           76
# 4                               جوراب زنانه مدل S855         9841
#
#             category_title_fa  is_buyer
# 0                 کابل و مبدل      True
# 1  پایه نگهدارنده گوشی و تبلت      True
# ...

# %%
Col = ['comment']
data = data[Col]
data.head()
# Out:
#                                              comment
# 0  معمولیه و زیاد کیفیتشم خوب نیست ولی در کل زیاد...
# 1               جنس خوبی داره با این قدر پول می ارزه
# 2                                     ایییی بدک نیست
# 3             خوبه بااین قیمت بهتر از این نمیشه گرفت
# 4                                    زیبا بود و ظریف

# %%
data['comment'] = data['comment'].apply(lambda x : len(x.split()))
data.head()
# Out:
#    comment
# 0       12
# 1        9
# 2        3
# 3        8
# 4        4
